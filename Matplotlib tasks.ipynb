# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
d= {"Length": np.random.randn(500)}

df= pd.DataFrame(d)
df
# Out:
#        Length
# 0    1.754223
# 1    1.925057
# 2   -0.116349
# 3   -0.655261
# 4    0.314278
# ..        ...
# 495  1.728009
# 496 -0.155224
# 497 -1.529367
# 498  0.928087
# 499 -0.103023
#
# [500 rows x 1 columns]

# %%
df.shape
# Out:
# (500, 1)

# %%
df['Length'].hist()
# Out:
# <AxesSubplot:>

# %%
plt.hist(df['Length'])
plt.xlabel("Length")
plt.ylabel("count/Frequency")
plt.title("Histogram of Length")
plt.show()

# %%
plt.hist(df['Length'],bins=15)
plt.show()

# %%
plt.hist(df['Length'], orientation='horizontal')
plt.xlabel("count")
plt.ylabel("Length")
plt.title("Histogram of Length")
plt.show()

# %%
plt.boxplot(df['Length'])
plt.show()

# %%
a = [2,7,3,0.2]
b = [1,3,0.7,4]

plt.scatter(a,b)
plt.show()

# %%
x =[1,2,0.4,8]
y =[1,3,0.7,4]

plt.scatter(x,y,c='red',marker="*")
plt.show()

# %%
y= [16,12,8,9,4,7,3,13,16]
plt.plot(y)
plt.show()

# %%
plt.plot([16,12,8,9,4,7,3,13,16],color="red",linewidth=1.0)
plt.show()

# %%
plt.plot([16,12,8,9,4,7,3,13,16],color="red")
plt.grid()
plt.text(7.5,16,'Lineplot')
plt.show()

# %%
x = [2,4,6,7,8,9,2,3,4,5]
y = [2,3,1,4,8,6,5,2,1,3]

plt.plot(x,y)
plt.show()

# %%
x=np.arange(6)
y=x
z=x**2
e=x**3

# %%
plt.plot(x,y)

# %%
plt.plot(x,z)

# %%
plt.plot(x, e)

# %%
plt.plot(x, y)
plt.plot(x, z)
plt.plot(x, e)
plt.show()

# %%
plt.plot(x,y, label='linear')
plt.plot(x,z, label='quadratic')
plt.plot(x,e, label='cubic')
plt.legend()
plt.show()

# %%
days = [1,2,3,4,5,6,7]

max_t=[50,51,52,48,47,49,46]
min_t=[43,42,40,44,33,35,37]
avg_t=[45,48,48,46,40,42,41]

plt.plot(days, max_t, label="max")
plt.plot(days, min_t, label="min")
plt.plot(days, avg_t, label="average")

plt.xlabel('Day')
plt.ylabel('Temperature')
plt.title('Weather')

plt.legend()
plt.show()

# %%
x=[1,2,3,4,5,6,7]
y=[50,51,52,48,47,49,46]

plt.subplot(3,2,1)
plt.plot(x,y,color='green',marker='*',linestyle='dashed')
plt.title("line plot")

plt.subplot(3,2,2)
plt.scatter(x,y)
plt.title("scatter plot")

plt.subplot(3,2,3)
plt.plot(x,y,linewidth=3)

plt.subplot(3,2,6)
plt.plot(x,y,color="green",marker="o",linestyle='dashed')

plt.show()

# %%
#plotting the data
list= [20,30,19,11,8,7,5]
cars= ["jaguar","mercedes benz","BMW","mahindra","Tata","suzuki","hyundai"]

# %%
plt.pie(list,labels=cars,autopct='%1.1f%%',radius=1.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.pie(list,labels=cars,autopct='%1.1f%%',explode=[0,0.1,0,0.1,0,0,0])
plt.axis("equal")
plt.show()

# %%
#plotting data
ln = "python",'c++',"java","ruby"
sizes =[45,16,35,14]
colr=["red","green","skyblue","black"]
explode =(0.1,0,0,0)
#exploding first slice

#plotting
plt.pie(sizes,explode=explode,labels=ln,colors=colr,autopct="%1.1f%%")
plt.savefig("plot.jpg")
plt.show()

# %%
#bar plotting
list = [20,30,19,11,8,7,5]
cars= ["jaguar","mercedes benz","BMW","mahindra","Tata","suzuki","hyundai"]
plt.bar(cars,list)
plt.show()

# %%
company=["amazon","google","microsoft","facebook"]
revenue=[90,136,85,26]
plt.bar(company,revenue)
plt.ylabel("revenue($B)")
plt.title("US Technology stocks")
plt.show()

# %%
plt.barh(company,revenue)
plt.ylabel("revenue($B)")
plt.title("US Technology stocks")
plt.show()

# %%
company=["amazon","google","microsoft","facebook"]
revenue=[90,136,85,26]
profit=[40,20,30,12]
plt.bar(company,revenue,label="revenue")
plt.bar(company,profit,label="profit")
plt.title("US Technology Stocks")
plt.legend()
plt.show()

# %%
company=["amazon","google","microsoft","facebook"]
revenue=[90,136,85,26]
profit=[40,20,30,12]

xpos = np.arange(len(company))
plt.bar(xpos-0.2,revenue, width=0.4, label="revenue")
plt.bar(xpos+0.2,profit,width=0.4, label="profit")

plt.xticks(xpos,company)
plt.ylabel("revenue(Bln)")
plt.title("US Technology Stocks")
plt.legend()
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#multiple charts
ecommerce=['amazon','snapdeal','flipkart','myntra']
Q1_profit=['70','45','40','38']
Q2_profit=['65','40','45','38']
Q3_profit=['73','42','50','30']
Q4_profit=['60','41','48','25']

# %%
#using subplot
plt.figure(1,figsize=(10,10))

#first cell
plt.subplot(2,2,1)
plt.bar(ecommerce,Q1_profit)
plt.title("Quarter1 profit")

#second cell
plt.subplot(2,2,2)
plt.bar(ecommerce,Q2_profit)
plt.title("Quarter2 profit")

#Third cell
plt.subplot(2,2,3)
plt.bar(ecommerce,Q3_profit)
plt.title("Quarter3 profit")

#fourth cell
plt.subplot(2,2,4)
plt.bar(ecommerce,Q4_profit)
plt.title("Quarter4 profit")

#Adding title
plt.suptitle("profit on Quarterly Basis")

#Displaying the chart
plt.show()

# %%
mobile=['apple','oneplus','vivo','motrola']
Q1_profit=['71','42','44','36']
Q2_profit=['62','41','41','34']
Q3_profit=['74','48','52','30']
Q4_profit=['64','43','41','28']

# %%
plt.figure(1,figsize=(10,10))

plt.subplot(2,2,1)
plt.bar(mobile,Q1_profit)
plt.title("Quarter1 profit")

plt.subplot(2,2,2)
plt.bar(mobile,Q2_profit)
plt.title("Quarter2 profit")

plt.subplot(2,2,3)
plt.bar(mobile,Q3_profit)
plt.title("Quarter3 profit")

plt.subplot(2,2,4)
plt.bar(mobile,Q4_profit)
plt.title("Quarter4 profit")

plt.suptitle("profit on Quarterly Basis")

plt.show()
