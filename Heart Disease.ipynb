# %%
import pandas as pd
import numpy as np
import matplotlib as plt

# %%
df=pd.read_csv("Heart_Disease_Prediction.csv")

# %%
df
# Out:
#      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
df.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# BP                         0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
missing_value=["N/a","na",np.nan]

# %%
df.columns
# Out:
# Index(['Age', 'Sex', 'Chest pain type', 'BP', 'Cholesterol', 'FBS over 120',
#        'EKG results', 'Max HR', 'Exercise angina', 'ST depression',
#        'Slope of ST', 'Number of vessels fluro', 'Thallium', 'Heart Disease'],
#       dtype='object')

# %%
df1=df.rename(columns={'BP':'Blood Pressure'})

# %%
df1.head()
# Out:
#    Age  Sex  Chest pain type  Blood Pressure  Cholesterol  FBS over 120  \
# 0   70    1                4             130          322             0
# 1   67    0                3             115          564             0
# 2   57    1                2             124          261             0
# 3   64    1                4             128          263             0
# 4   74    0                2             120          269             0
#
#    EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0            2     109                0            2.4            2
# 1            2     160                0            1.6            2
# 2            0     141                0            0.3            1
# 3            0     105                1            0.2            2
# 4            2     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# ...

# %%
df1.tail()
# Out:
#      Age  Sex  Chest pain type  Blood Pressure  Cholesterol  FBS over 120  \
# 265   52    1                3             172          199             1
# 266   44    1                2             120          263             0
# 267   56    0                2             140          294             0
# 268   57    1                4             140          192             0
# 269   67    1                4             160          286             0
#
#      EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 265            0     162                0            0.5            1
# 266            0     173                0            0.0            1
# 267            2     153                0            1.3            2
# 268            0     148                0            0.4            2
# 269            2     108                1            1.5            2
#
#      Number of vessels fluro  Thallium Heart Disease
# ...

# %%
df1.describe()
# Out:
#               Age         Sex  Chest pain type          BP  Cholesterol  \
# count  270.000000  270.000000       270.000000  270.000000   270.000000
# mean    54.433333    0.677778         3.174074  131.344444   249.659259
# std      9.109067    0.468195         0.950090   17.861608    51.686237
# min     29.000000    0.000000         1.000000   94.000000   126.000000
# 25%     48.000000    0.000000         3.000000  120.000000   213.000000
# 50%     55.000000    1.000000         3.000000  130.000000   245.000000
# 75%     61.000000    1.000000         4.000000  140.000000   280.000000
# max     77.000000    1.000000         4.000000  200.000000   564.000000
#
#        FBS over 120  EKG results      Max HR  Exercise angina  ST depression  \
# count    270.000000   270.000000  270.000000       270.000000      270.00000
# mean       0.148148     1.022222  149.677778         0.329630        1.05000
# std        0.355906     0.997891   23.165717         0.470952        1.14521
# ...

# %%
df1.index
# Out:
# RangeIndex(start=0, stop=270, step=1)

# %%
df1.columns.str.upper()
# Out:
# Index(['AGE', 'SEX', 'CHEST PAIN TYPE', 'BLOOD PRESSURE', 'CHOLESTEROL',
#        'FBS OVER 120', 'EKG RESULTS', 'MAX HR', 'EXERCISE ANGINA',
#        'ST DEPRESSION', 'SLOPE OF ST', 'NUMBER OF VESSELS FLURO', 'THALLIUM',
#        'HEART DISEASE'],
#       dtype='object')

# %%
df1.isnull()
# Out:
#        Age    Sex  Chest pain type  Blood Pressure  Cholesterol  FBS over 120  \
# 0    False  False            False           False        False         False
# 1    False  False            False           False        False         False
# 2    False  False            False           False        False         False
# 3    False  False            False           False        False         False
# 4    False  False            False           False        False         False
# ..     ...    ...              ...             ...          ...           ...
# 265  False  False            False           False        False         False
# 266  False  False            False           False        False         False
# 267  False  False            False           False        False         False
# 268  False  False            False           False        False         False
# 269  False  False            False           False        False         False
#
# ...

# %%
df1.isnull().any()
# Out:
# Age                        False
# Sex                        False
# Chest pain type            False
# Blood Pressure             False
# Cholesterol                False
# FBS over 120               False
# EKG results                False
# Max HR                     False
# Exercise angina            False
# ST depression              False
# Slope of ST                False
# Number of vessels fluro    False
# Thallium                   False
# Heart Disease              False
# dtype: bool

# %%
#columns with Nan using Integer
df1.isnull().sum()
# Out:
# Age                        0
# Sex                        0
# Chest pain type            0
# Blood Pressure             0
# Cholesterol                0
# FBS over 120               0
# EKG results                0
# Max HR                     0
# Exercise angina            0
# ST depression              0
# Slope of ST                0
# Number of vessels fluro    0
# Thallium                   0
# Heart Disease              0
# dtype: int64

# %%
#total number of missing NA
df1.isnull().sum().sum()
# Out:
# 0

# %%
#filling missing values
df1.head()
# Out:
#    Age  Sex  Chest pain type  Blood Pressure  Cholesterol  FBS over 120  \
# 0   70    1                4             130          322             0
# 1   67    0                3             115          564             0
# 2   57    1                2             124          261             0
# 3   64    1                4             128          263             0
# 4   74    0                2             120          269             0
#
#    EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0            2     109                0            2.4            2
# 1            2     160                0            1.6            2
# 2            0     141                0            0.3            1
# 3            0     105                1            0.2            2
# 4            2     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# ...

# %%
df2=df1.fillna(0)

# %%
#fill with mean
df1['Blood Pressure'].mean()
# Out:
# 131.34444444444443

# %%
df3=df1.fillna(df1['Blood Pressure'].mean())

# %%
df3.head()
# Out:
#    Age  Sex  Chest pain type  Blood Pressure  Cholesterol  FBS over 120  \
# 0   70    1                4             130          322             0
# 1   67    0                3             115          564             0
# 2   57    1                2             124          261             0
# 3   64    1                4             128          263             0
# 4   74    0                2             120          269             0
#
#    EKG results  Max HR  Exercise angina  ST depression  Slope of ST  \
# 0            2     109                0            2.4            2
# 1            2     160                0            1.6            2
# 2            0     141                0            0.3            1
# 3            0     105                1            0.2            2
# 4            2     121                1            0.2            1
#
#    Number of vessels fluro  Thallium Heart Disease
# 0                        3         3      Presence
# ...

# %%
df.shape
# Out:
# (270, 14)

# %%
#drop NA values
df_drop=df.dropna()

# %%
df.drop
# Out:
# <bound method DataFrame.drop of      Age  Sex  Chest pain type   BP  Cholesterol  FBS over 120  EKG results  \
# 0     70    1                4  130          322             0            2
# 1     67    0                3  115          564             0            2
# 2     57    1                2  124          261             0            0
# 3     64    1                4  128          263             0            0
# 4     74    0                2  120          269             0            2
# ..   ...  ...              ...  ...          ...           ...          ...
# 265   52    1                3  172          199             1            0
# 266   44    1                2  120          263             0            0
# 267   56    0                2  140          294             0            2
# 268   57    1                4  140          192             0            0
# 269   67    1                4  160          286             0            2
#
# ...

# %%
#drop duplicates
# ?df.dropna

# %%
df_cond=df1.dropna(thresh=2)

# %%
df_cond.shape
# Out:
# (270, 14)

# %%
#drops columns with na
df_drop_column=df.dropna(axis=1) #axis=1 is y-axis

# %%
df1.head()
# Out:
#    Age  Sex  Chest pain type  Cholesterol  FBS over 120  EKG results  Max HR  \
# 0   70    1                4          322             0            2     109
# 1   67    0                3          564             0            2     160
# 2   57    1                2          261             0            0     141
# 3   64    1                4          263             0            0     105
# 4   74    0                2          269             0            2     121
#
#    Exercise angina  Slope of ST  Number of vessels fluro  Thallium  \
# 0                0            2                        3         3
# 1                0            2                        0         7
# 2                0            1                        0         7
# 3                1            2                        1         7
# 4                1            1                        1         3
#
#   Heart Disease
# 0      Presence
# 1       Absence
# 2      Presence
# 3       Absence
# ...

# %%
df1.shape
# Out:
# (270, 12)

# %%
df4=df1.drop(df.columns[2],axis=1,inplace=True)

# %%
df1.head()
# Out:
#    Age  Sex  Chest pain type  FBS over 120  EKG results  Max HR  \
# 0   70    1                4             0            2     109
# 1   67    0                3             0            2     160
# 2   57    1                2             0            0     141
# 3   64    1                4             0            0     105
# 4   74    0                2             0            2     121
#
#    Exercise angina  Slope of ST  Number of vessels fluro  Thallium  \
# 0                0            2                        3         3
# 1                0            2                        0         7
# 2                0            1                        0         7
# 3                1            2                        1         7
# 4                1            1                        1         3
#
#   Heart Disease
# 0      Presence
# 1       Absence
# 2      Presence
# 3       Absence
# 4       Absence

# %%
df1.shape
# Out:
# (270, 11)

# %%
df1.loc[[2,4]]
# Out:
#    Age  Sex  Chest pain type  FBS over 120  EKG results  Max HR  \
# 2   57    1                2             0            0     141
# 4   74    0                2             0            2     121
#
#    Exercise angina  Slope of ST  Number of vessels fluro  Thallium  \
# 2                0            1                        0         7
# 4                1            1                        1         3
#
#   Heart Disease
# 2      Presence
# 4       Absence

# %%
df1.iloc[2,4]
# Out:
# 0

# %%
df1.iloc[[1,2,-1]]
# Out:
#      Age  Sex  Chest pain type  FBS over 120  EKG results  Max HR  \
# 1     67    0                3             0            2     160
# 2     57    1                2             0            0     141
# 269   67    1                4             0            2     108
#
#      Exercise angina  Slope of ST  Number of vessels fluro  Thallium  \
# 1                  0            2                        0         7
# 2                  0            1                        0         7
# 269                1            2                        3         3
#
#     Heart Disease
# 1         Absence
# 2        Presence
# 269      Presence

# %%
df1.loc[:,['Max HR','Slope of ST']]
# Out:
#      Max HR  Slope of ST
# 0       109            2
# 1       160            2
# 2       141            1
# 3       105            2
# 4       121            1
# ..      ...          ...
# 265     162            1
# 266     173            1
# 267     153            2
# 268     148            2
# 269     108            2
#
# [270 rows x 2 columns]

# %%
df1.loc[df1['Heart Disease']=='Presence']
# Out:
#      Age  Sex  Chest pain type  FBS over 120  EKG results  Max HR  \
# 0     70    1                4             0            2     109
# 2     57    1                2             0            0     141
# 6     56    1                3             1            2     142
# 7     59    1                4             0            2     142
# 8     60    1                4             0            2     170
# ..   ...  ...              ...           ...          ...     ...
# 258   64    1                3             0            0     158
# 261   60    1                4             0            2     132
# 262   58    1                2             0            2     160
# 264   48    1                2             0            0     168
# 269   67    1                4             0            2     108
#
#      Exercise angina  Slope of ST  Number of vessels fluro  Thallium  \
# 0                  0            2                        3         3
# ...

# %%
df1.loc[(df1['Heart Disease']=='Presence')&(df1['Max HR']=='168')]
# Out:
# Empty DataFrame
# Columns: [Age, Sex, Chest pain type, FBS over 120, EKG results, Max HR, Exercise angina, Slope of ST, Number of vessels fluro, Thallium, Heart Disease]
# Index: []

# %%
df.groupby(['Thallium'])['Number of vessels fluro'].mean()
# Out:
# Thallium
# 3    0.431579
# 6    0.666667
# 7    0.876712
# Name: Number of vessels fluro, dtype: float64

# %%
df.groupby(['Thallium'])['Number of vessels fluro'].agg(np.mean)
# Out:
# Thallium
# 3    0.431579
# 6    0.666667
# 7    0.876712
# Name: Number of vessels fluro, dtype: float64

# %%
df.groupby(['Thallium'])['Number of vessels fluro'].agg(np.std)
# Out:
# Thallium
# 3    0.820646
# 6    0.984732
# 7    1.013043
# Name: Number of vessels fluro, dtype: float64

# %%
df.groupby(['Thallium'])['Number of vessels fluro'].agg(np.median)
# Out:
# Thallium
# 3    0.0
# 6    0.0
# 7    1.0
# Name: Number of vessels fluro, dtype: float64

# %%
df.groupby(['Thallium','Number of vessels fluro'])[['EKG results','FBS over 120']].agg(np.mean)
# Out:
#                                   EKG results  FBS over 120
# Thallium Number of vessels fluro
# 3        0                           0.942857      0.114286
#          1                           1.538462      0.230769
#          2                           0.750000      0.125000
#          3                           2.000000      0.000000
# 6        0                           0.857143      0.142857
#          1                           1.333333      0.666667
#          2                           2.000000      0.000000
#          3                           0.000000      0.000000
# 7        0                           1.000000      0.205882
#          1                           0.818182      0.045455
#          2                           1.555556      0.111111
#          3                           1.500000      0.125000

# %%
df.groupby(['Thallium','Number of vessels fluro'])[['EKG results','FBS over 120']].agg(np.mean).reset_index()
# Out:
#     Thallium  Number of vessels fluro  EKG results  FBS over 120
# 0          3                        0     0.942857      0.114286
# 1          3                        1     1.538462      0.230769
# 2          3                        2     0.750000      0.125000
# 3          3                        3     2.000000      0.000000
# 4          6                        0     0.857143      0.142857
# 5          6                        1     1.333333      0.666667
# 6          6                        2     2.000000      0.000000
# 7          6                        3     0.000000      0.000000
# 8          7                        0     1.000000      0.205882
# 9          7                        1     0.818182      0.045455
# 10         7                        2     1.555556      0.111111
# 11         7                        3     1.500000      0.125000

# %%
df1.count(Tha)
