# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("stock_data.csv")

# %%
df.head()
# Out:
#          Date     Open     High      Low    Close    Volume  OpenInt Stock
# 0  1984-09-07  0.42388  0.42902  0.41874  0.42388  23220030        0  AAPL
# 1  1984-09-10  0.42388  0.42516  0.41366  0.42134  18022532        0  AAPL
# 2  1984-09-11  0.42516  0.43668  0.42516  0.42902  42498199        0  AAPL
# 3  1984-09-12  0.42902  0.43157  0.41618  0.41618  37125801        0  AAPL
# 4  1984-09-13  0.43927  0.44052  0.43927  0.43927  57822062        0  AAPL

# %%
df.describe()
# Out:
#                Open          High           Low         Close        Volume  \
# count  19586.000000  19586.000000  19586.000000  19586.000000  1.958600e+04
# mean      37.408582     37.881571     36.906405     37.406667  8.100395e+07
# std       59.492049     60.287797     58.622548     59.480058  7.982366e+07
# min        0.067200      0.067200      0.067200      0.067200  0.000000e+00
# 25%        1.412300      1.440600      1.384100      1.412300  3.385552e+07
# 50%       19.649500     19.933000     19.363000     19.640000  6.294731e+07
# 75%       38.605000     39.075750     38.229250     38.655500  1.010604e+08
# max      386.690000    389.610000    379.345000    385.000000  2.069770e+09
#
#        OpenInt
# count  19586.0
# mean       0.0
# std        0.0
# min        0.0
# 25%        0.0
# 50%        0.0
# 75%        0.0
# max        0.0

# %%
df.columns
# Out:
# Index(['Date', 'Open', 'High', 'Low', 'Close', 'Volume', 'OpenInt', 'Stock'], dtype='object')

# %%
df.isnull()
# Out:
#         Date   Open   High    Low  Close  Volume  OpenInt  Stock
# 0      False  False  False  False  False   False    False  False
# 1      False  False  False  False  False   False    False  False
# 2      False  False  False  False  False   False    False  False
# 3      False  False  False  False  False   False    False  False
# 4      False  False  False  False  False   False    False  False
# ...      ...    ...    ...    ...    ...     ...      ...    ...
# 19581  False  False  False  False  False   False    False  False
# 19582  False  False  False  False  False   False    False  False
# 19583  False  False  False  False  False   False    False  False
# 19584  False  False  False  False  False   False    False  False
# 19585  False  False  False  False  False   False    False  False
#
# [19586 rows x 8 columns]

# %%
df.isnull().sum()
# Out:
# Date       0
# Open       0
# High       0
# Low        0
# Close      0
# Volume     0
# OpenInt    0
# Stock      0
# dtype: int64

# %%
df.shape
# Out:
# (19586, 8)

# %%
df.dropna()
# Out:
#              Date       Open       High        Low      Close    Volume  \
# 0      1984-09-07    0.42388    0.42902    0.41874    0.42388  23220030
# 1      1984-09-10    0.42388    0.42516    0.41366    0.42134  18022532
# 2      1984-09-11    0.42516    0.43668    0.42516    0.42902  42498199
# 3      1984-09-12    0.42902    0.43157    0.41618    0.41618  37125801
# 4      1984-09-13    0.43927    0.44052    0.43927    0.43927  57822062
# ...           ...        ...        ...        ...        ...       ...
# 19581  2017-11-06  178.56000  180.45000  178.31000  180.17000  13275578
# 19582  2017-11-07  180.50000  180.74800  179.40300  180.25000  12903836
# 19583  2017-11-08  179.79000  180.35000  179.11000  179.56000  10467606
# 19584  2017-11-09  178.31000  179.40000  177.09000  179.30000  12602188
# 19585  2017-11-10  178.35000  179.10000  177.96000  178.46000  11060355
#
#        OpenInt Stock
# 0            0  AAPL
# 1            0  AAPL
# 2            0  AAPL
# 3            0  AAPL
# 4            0  AAPL
# ...        ...   ...
# 19581        0    FB
# 19582        0    FB
# 19583        0    FB
# 19584        0    FB
# 19585        0    FB
#
# [19586 rows x 8 columns]

# %%
df.duplicated().sum()
# Out:
# 0

# %%
sns.pairplot(df)

# %%
df['Open'].plot(figsize=(10,5))
# Out:
# <AxesSubplot:>

# %%
X=df[['Open','High','Low','Volume']]

# %%
print(X)
# Out:
#             Open       High        Low    Volume
# 0        0.42388    0.42902    0.41874  23220030
# 1        0.42388    0.42516    0.41366  18022532
# 2        0.42516    0.43668    0.42516  42498199
# 3        0.42902    0.43157    0.41618  37125801
# 4        0.43927    0.44052    0.43927  57822062
# ...          ...        ...        ...       ...
# 19581  178.56000  180.45000  178.31000  13275578
# 19582  180.50000  180.74800  179.40300  12903836
# 19583  179.79000  180.35000  179.11000  10467606
# 19584  178.31000  179.40000  177.09000  12602188
# 19585  178.35000  179.10000  177.96000  11060355
#
# [19586 rows x 4 columns]

# %%
y=df['Close']

# %%
print(y)
# Out:
# 0          0.42388
# 1          0.42134
# 2          0.42902
# 3          0.41618
# 4          0.43927
#            ...
# 19581    180.17000
# 19582    180.25000
# 19583    179.56000
# 19584    179.30000
# 19585    178.46000
# Name: Close, Length: 19586, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y, test_size=0.2, random_state=1)

# %%
X_train.shape
# Out:
# (15668, 4)

# %%
X_test.shape
# Out:
# (3918, 4)

# %%
y_train.shape
# Out:
# (15668,)

# %%
y_test.shape
# Out:
# (3918,)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix,accuracy_score

# %%
reg=LinearRegression()

# %%
reg.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-6.04386453e-01,  8.47706560e-01,  7.56035260e-01, -1.11046110e-11])

# %%
reg.intercept_
# Out:
# 0.0017275560135487922

# %%
pred=reg.predict(X_test)

# %%
print(X_test)
# Out:
#            Open      High       Low     Volume
# 1251    1.33660   1.35990   1.32940   23444913
# 7927   93.22600  93.79800  92.84900   34204278
# 4       0.43927   0.44052   0.43927   57822062
# 10266   0.08389   0.08389   0.08389    5052632
# 5378    9.62800   9.73000   9.54000  172662101
# ...         ...       ...       ...        ...
# 16686  22.76800  22.93100  22.61400   55082456
# 18292  22.97000  23.24000  22.60000   51198709
# 5743   15.97400  16.00800  15.74200  263011080
# 7021   77.21400  77.75900  76.83700   86874978
# 16362  21.46600  21.50900  20.94700   87054231
#
# [3918 rows x 4 columns]

# %%
pred.shape
# Out:
# (3918,)

# %%
df2=pd.DataFrame(y_test,pred)

# %%
df3=pd.DataFrame({'Actual':y_test,'Predicted':pred})

# %%
print(df3)
# Out:
#          Actual  Predicted
# 1251    1.35240   1.351514
# 7927   93.77800  93.367114
# 4       0.43927   0.441132
# 10266   0.08389   0.085507
# 5378    9.60000   9.641539
# ...         ...        ...
# 16686  22.62100  22.776186
# 18292  22.86000  22.905500
# 5743   15.83600  15.815931
# 7021   77.47400  77.341963
# 16362  21.06600  21.096992
#
# [3918 rows x 2 columns]

# %%
df3.head(10)
# Out:
#           Actual   Predicted
# 1251     1.35240    1.351514
# 7927    93.77800   93.367114
# 4        0.43927    0.441132
# 10266    0.08389    0.085507
# 5378     9.60000    9.641539
# 3501     1.10260    1.100625
# 5322     6.88220    6.789706
# 565      0.66210    0.658413
# 19465  148.07000  147.711515
# 3394     0.62240    0.621983

# %%
reg.score(X_test,y_test)
# Out:
# 0.9999069317731827

# %%
gr=df3.head(10)

# %%
gr.plot(kind='bar')
# Out:
# <AxesSubplot:>
